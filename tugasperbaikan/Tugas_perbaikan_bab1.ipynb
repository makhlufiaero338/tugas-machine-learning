# %% [markdown]
# <a href="https://colab.research.google.com/github/makhlufiaero338/tugas-machine-learning/blob/main/tugasperbaikan/Tugas_perbaikan_bab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Load the Iris dataset
iris = load_iris()

# View dataset description
print(iris.DESCR)

# View features and labels
print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)

# Convert to DataFrame for better visualization
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
df.head()
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.25, random_state=42
)

print(f"Training set size: {X_train.shape[0]} samples")
print(f"Testing set size: {X_test.shape[0]} samples")
# Out:
# Training set size: 112 samples
# Testing set size: 38 samples

# %%
# Visualize the data
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    iris.data[:, 0], iris.data[:, 1], c=iris.target, cmap='viridis', edgecolor='k'
)
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title("Scatter Plot of Iris Dataset")
plt.legend(handles=scatter.legend_elements()[0], labels=iris.target_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d4d4fcd49ab8> in <cell line: 9>()
#       7 plt.ylabel(iris.feature_names[1])
#       8 plt.title("Scatter Plot of Iris Dataset")
# ----> 9 plt.legend(handles=scatter.legend_elements()[0], labels=iris.target_names)
#      10 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3370 @_copy_docstring_and_deprecators(Axes.legend)
#    3371 def legend(*args, **kwargs) -> Legend:
# -> 3372     return gca().legend(*args, **kwargs)
#    3373
#    3374
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     320         .. plot:: gallery/text_labels_and_annotations/legend.py
#     321         """
# --> 322         handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# ...

# %%
# Build k-Nearest Neighbors model
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Make predictions
y_pred = knn.predict(X_test)

# Display predictions and actual labels
print("Predicted labels:", y_pred)
print("Actual labels:   ", y_test)
# Out:
# Predicted labels: [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0]
# Actual labels:    [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0]

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy * 100:.2f}%")
# Out:
# Model accuracy: 100.00%

# %% [markdown]
# 1. A First Application: Classifying Iris Species
# Tujuan: Membuat model pembelajaran mesin pertama untuk mengklasifikasikan jenis bunga Iris berdasarkan fitur seperti panjang dan lebar kelopak.
# Pustaka: Gunakan scikit-learn untuk memanfaatkan dataset Iris yang tersedia secara bawaan.
# 2. Meet the Data
# Dataset Iris: Dataset berisi informasi tentang tiga spesies bunga (Setosa, Versicolor, Virginica) dengan empat fitur:
# Sepal length
# Sepal width
# Petal length
# Petal width
# Deskripsi Dataset: Periksa detail data, seperti nama fitur, label target, dan deskripsi dataset untuk memahami struktur data.
# Konversi ke DataFrame: Ubah dataset menjadi DataFrame menggunakan pandas untuk memudahkan eksplorasi data.
# 3. Measuring Success: Training and Testing Data
# Split Data: Dataset dibagi menjadi dua bagian:
# Training Set: Untuk melatih model.
# Testing Set: Untuk menguji kinerja model.
# Tujuan: Menghindari overfitting dan memastikan model dapat bekerja baik pada data baru.
# 4. First Things First: Look at Your Data
# Visualisasi: Gunakan scatter plot untuk memvisualisasikan dua fitur dataset (misalnya, panjang dan lebar sepal) dan memeriksa bagaimana data tersebar untuk setiap spesies.
# Tujuan: Membantu memahami pola dalam data dan mempersiapkan diri untuk memilih algoritma yang cocok.
# 5. Building Your First Model: k-Nearest Neighbors
# K-Nearest Neighbors (k-NN): Algoritma yang memprediksi label berdasarkan label dari k tetangga terdekatnya dalam ruang fitur.
# Langkah:
# Tentukan jumlah tetangga (k), misalnya 3.
# Latih model dengan data training menggunakan fit dari scikit-learn.
# 6. Making Predictions
# Prediksi: Gunakan model yang sudah dilatih untuk memprediksi label pada data testing.
# Hasil: Periksa label yang diprediksi model dan bandingkan dengan label asli untuk melihat apakah model bekerja dengan baik.
# 7. Evaluating the Model
# Evaluasi Kinerja: Hitung akurasi model menggunakan accuracy_score dari scikit-learn, yang menunjukkan persentase prediksi yang benar.
# Tujuan: Mengukur seberapa baik model dapat memprediksi data yang belum pernah dilihat.
